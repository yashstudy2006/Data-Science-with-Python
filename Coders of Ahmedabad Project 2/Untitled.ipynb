# %% [markdown]
# ## Data Collection in Ahmedabad
#
# You hire Sonali and Icsha to help with the project. Sonali lives all the way in Hebbal, and Icsh stays in HSR Layout, so meeting at either place would be a long trip for someone.
# To keep things fair, you decide to set up a meeting at Café in Ahmedabad, a perfect midway point.
#
# ## Three of you sit down and lay out the entire project plan. You break the work into two major parts:
#
# ~ Sonali and Icsha will be in charge of collecting the Instagram follower data.
# ~ You will build the Python Script that will process everything.
#
# By the end of the meeting, everyone is aligned: Sonali and Icsha will focus on accurate data collection, and you’ll focus on making sure the code can handle real-world data seamlessly.
#
# The team is ready, the plan is set, and the project officially kicks off.
#
#
# # Welcome Sam Altman to Ahmedabad
#
# You ask Sam Altman for 2.2 billion USD in funding, and he makes fun of you in public
# He asks you where you live, and finally, after talking to you, gives you a challenging task
# Collect raw Instagram data of all Open AI followers
#
# Answer these questions:
# Who has the maximum posts
# who has the maximum followers
# Who follows the maximum people
#
# How many categories (Digital creators, Non-profit foundation, etc do we have? How many people do we have?
# You have 24 hours!
#
# You then ask for data - he laughs!

# %% [markdown]
# ## Data collection
# You hire Sonali and Icsha who are from Hebbal and HSR layout respectively
# HSR layout and Hebbal are far away so u set up a meeting at Cafe, Ahmedabad!

# %%
with open ("data.txt", encoding='utf-8')as f:
    data = f.read()

# %%
data
# Out:
# 'tech_world_raj\n210 posts\n12,500 followers\n340 following\nRaj | Tech Reviews\nScience & Technology\nSmartphones | AI | Gadgets Honest reviews & tips DM for collaborations\ntechworldraj.com\n\nfit_with_aarav\n540 posts\n18,000 followers\n420 following\nAarav | Fitness Coach\nHealth & Wellness\n💪 Transform Your Body\nDiet | Workout | Motivation\nOnline coaching available\nfitwithaarav.in\n\ntravel_diaries_riya\n185 posts\n9,800 followers\n290 following\nRiya | Travel Blogger\nTravel\nExploring Hidden Places\nBudget Travel Tips\nDM for partnerships\nriyatravels.com\n\nfoodie_krishna\n760 posts\n22,000 followers\n610 following\nKrishna | Food Lover\nFood & Drink\nStreet Food Explorer\nReviews & Recipes\nDM for collabs\nzomato.com\n\ncode_with_neha\n134 posts\n15,000 followers\n180 following\nNeha | Software Engineer\nEducation\n💻 Python | DSA | AI\n🚀 Helping Beginners Learn Coding\n📩 Workshops & Mentorship\ncodewithneha.dev\n\nstartup_guru\n98 posts\n31,000 followers\n540 following\nStartup Guru\nBusiness\n🚀 Startup News & Funding\n💼 Founder Stories\n📩 Feature your startup\nstartupguru.in\n\nnature_clicks\n480 posts\n14,000 followers\n260 following\nNature Clicks\nPhotography\n🌿 Wildlife & Landscapes\n📸 Shot on DSLR\n📩 Prints Available\nnatureclicks.com\n\ngaming_arena\n390 posts\n42,000 followers\n710 following\nGaming Arena\nGaming\n🎮 PC & Mobile Games\n🔥 Live Streams Daily\n📩 Brand Collaborations\ngamingarena.gg\n\nfashion_by_isha\n620 posts\n28,000 followers\n530 following\nIsha | Fashion Creator\nFashion\n👗 Daily Outfit Inspiration\n✨ Beauty & Lifestyle\n📩 DM for promotions\nfashionbyisha.com\n\nfinance_with_kunal\n205 posts\n17,000 followers\n240 following\nKunal | Finance\nFinance\n📈 Stock Market\n💰 Investing Tips\n📩 Business inquiries\nfinancewithkunal.in\n\npet_lovers_club\n315 posts\n11,000 followers\n350 following\nPet Lovers Club\nAnimals\n🐶 Dogs | Cats | Pets\n❤️ Pet Care Tips\n📩 Feature your pet\npetloversclub.com\n\nmusic_vibes\n870 posts\n39,000 followers\n430 following\nMusic Vibes\nMusic\n🎵 Discover New Songs\n🎧 Daily Playlists\n📩 Promotions Open\nmusicvibes.fm\n\nart_by_sana\n154 posts\n8,900 followers\n170 following\nSana | Artist\nArt\n🎨 Digital & Traditional Art\n🖌️ Commission Open\n📩 DM to Order\nartbysana.com\n\ndaily_motivation\n1,020 posts\n55,000 followers\n120 following\nDaily Motivation\nEducation\n🔥 Quotes & Success Stories\n🌟 Inspire Every Day\n📩 Partnership Requests\ndailymotivation.in\n\nai_future_lab\n265 posts\n26,000 followers\n310 following\nAI Future Lab\nArtificial Intelligence\n🤖 AI Tools & News\n🧠 Machine Learning Updates\n📩 Business Contact\naifuturelab.ai'

# %%
chunks = data.split("\n\n")

# %%
chunks
# Out:
# ['tech_world_raj\n210 posts\n12,500 followers\n340 following\nRaj | Tech Reviews\nScience & Technology\nSmartphones | AI | Gadgets Honest reviews & tips DM for collaborations\ntechworldraj.com',
#  'fit_with_aarav\n540 posts\n18,000 followers\n420 following\nAarav | Fitness Coach\nHealth & Wellness\n💪 Transform Your Body\nDiet | Workout | Motivation\nOnline coaching available\nfitwithaarav.in',
#  'travel_diaries_riya\n185 posts\n9,800 followers\n290 following\nRiya | Travel Blogger\nTravel\nExploring Hidden Places\nBudget Travel Tips\nDM for partnerships\nriyatravels.com',
#  'foodie_krishna\n760 posts\n22,000 followers\n610 following\nKrishna | Food Lover\nFood & Drink\nStreet Food Explorer\nReviews & Recipes\nDM for collabs\nzomato.com',
#  'code_with_neha\n134 posts\n15,000 followers\n180 following\nNeha | Software Engineer\nEducation\n💻 Python | DSA | AI\n🚀 Helping Beginners Learn Coding\n📩 Workshops & Mentorship\ncodewithneha.dev',
#  'startup_guru\n98 posts\n31,000 followers\n540 following\nStartup Guru\nBusiness\n🚀 Startup News & Funding\n💼 Founder Stories\n📩 Feature your startup\nstartupguru.in',
#  'nature_clicks\n480 posts\n14,000 followers\n260 following\nNature Clicks\nPhotography\n🌿 Wildlife & Landscapes\n📸 Shot on DSLR\n📩 Prints Available\nnatureclicks.com',
#  'gaming_arena\n390 posts\n42,000 followers\n710 following\nGaming Arena\nGaming\n🎮 PC & Mobile Games\n🔥 Live Streams Daily\n📩 Brand Collaborations\ngamingarena.gg',
#  'fashion_by_isha\n620 posts\n28,000 followers\n530 following\nIsha | Fashion Creator\nFashion\n👗 Daily Outfit Inspiration\n✨ Beauty & Lifestyle\n📩 DM for promotions\nfashionbyisha.com',
#  'finance_with_kunal\n205 posts\n17,000 followers\n240 following\nKunal | Finance\nFinance\n📈 Stock Market\n💰 Investing Tips\n📩 Business inquiries\nfinancewithkunal.in',
#  'pet_lovers_club\n315 posts\n11,000 followers\n350 following\nPet Lovers Club\nAnimals\n🐶 Dogs | Cats | Pets\n❤️ Pet Care Tips\n📩 Feature your pet\npetloversclub.com',
#  'music_vibes\n870 posts\n39,000 followers\n430 following\nMusic Vibes\nMusic\n🎵 Discover New Songs\n🎧 Daily Playlists\n📩 Promotions Open\nmusicvibes.fm',
#  'art_by_sana\n154 posts\n8,900 followers\n170 following\nSana | Artist\nArt\n🎨 Digital & Traditional Art\n🖌️ Commission Open\n📩 DM to Order\nartbysana.com',
#  'daily_motivation\n1,020 posts\n55,000 followers\n120 following\nDaily Motivation\nEducation\n🔥 Quotes & Success Stories\n🌟 Inspire Every Day\n📩 Partnership Requests\ndailymotivation.in',
#  'ai_future_lab\n265 posts\n26,000 followers\n310 following\nAI Future Lab\nArtificial Intelligence\n🤖 AI Tools & News\n🧠 Machine Learning Updates\n📩 Business Contact\naifuturelab.ai']

# %%
chunks [4]
# Out:
# 'code_with_neha\n134 posts\n15,000 followers\n180 following\nNeha | Software Engineer\nEducation\n💻 Python | DSA | AI\n🚀 Helping Beginners Learn Coding\n📩 Workshops & Mentorship\ncodewithneha.dev'

# %%
def parse_chunk(chunk):
    try:
        chunk = chunk.strip()
        sep_chunk = chunk.split('\n')
        username = sep_chunk[0]
        no_of_post = sep_chunk[1]
        no_of_followers = sep_chunk[2]
        no_of_following = sep_chunk[2]
        name = sep_chunk[4]
        if (len(sep_chunk)>5):
            type_of_page = sep_chunk[5]
            bio = "\n".join(sep_chunk[6:])
        else:
            type_of_page = "Unknown"
            bio =""
        # print (username, no_of_post, no_of_followers, no_of_following, name, type_of_page, bio, sep="\n")
        return{"username": username,"no_of_ posts": no_of_post,"no_of_followers": no_of_followers, "no_of_following": no_of_following, "name": name, "type_of_page": type_of_page, "bio": bio}
    except  Exception as e:
        print(e, chunk)
#parse_chunk(chunks[0])

# %%
all_chunks = []
for chunk in chunks:
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'tech_world_raj', 'no_of_ posts': '210 posts', 'no_of_followers': '12,500 followers', 'no_of_following': '12,500 followers', 'name': 'Raj | Tech Reviews', 'type_of_page': 'Science & Technology', 'bio': 'Smartphones | AI | Gadgets Honest reviews & tips DM for collaborations\ntechworldraj.com'}, {'username': 'fit_with_aarav', 'no_of_ posts': '540 posts', 'no_of_followers': '18,000 followers', 'no_of_following': '18,000 followers', 'name': 'Aarav | Fitness Coach', 'type_of_page': 'Health & Wellness', 'bio': '💪 Transform Your Body\nDiet | Workout | Motivation\nOnline coaching available\nfitwithaarav.in'}, {'username': 'travel_diaries_riya', 'no_of_ posts': '185 posts', 'no_of_followers': '9,800 followers', 'no_of_following': '9,800 followers', 'name': 'Riya | Travel Blogger', 'type_of_page': 'Travel', 'bio': 'Exploring Hidden Places\nBudget Travel Tips\nDM for partnerships\nriyatravels.com'}, {'username': 'foodie_krishna', 'no_of_ posts': '760 posts', 'no_of_followers': '22,000 followers', 'no_of_following': '22,000 followers', 'name': 'Krishna | Food Lover', 'type_of_page': 'Food & Drink', 'bio': 'Street Food Explorer\nReviews & Recipes\nDM for collabs\nzomato.com'}, {'username': 'code_with_neha', 'no_of_ posts': '134 posts', 'no_of_followers': '15,000 followers', 'no_of_following': '15,000 followers', 'name': 'Neha | Software Engineer', 'type_of_page': 'Education', 'bio': '💻 Python | DSA | AI\n🚀 Helping Beginners Learn Coding\n📩 Workshops & Mentorship\ncodewithneha.dev'}, {'username': 'startup_guru', 'no_of_ posts': '98 posts', 'no_of_followers': '31,000 followers', 'no_of_following': '31,000 followers', 'name': 'Startup Guru', 'type_of_page': 'Business', 'bio': '🚀 Startup News & Funding\n💼 Founder Stories\n📩 Feature your startup\nstartupguru.in'}, {'username': 'nature_clicks', 'no_of_ posts': '480 posts', 'no_of_followers': '14,000 followers', 'no_of_following': '14,000 followers', 'name': 'Nature Clicks', 'type_of_page': 'Photography', 'bio': '🌿 Wildlife & Landscapes\n📸 Shot on DSLR\n📩 Prints Available\nnatureclicks.com'}, {'username': 'gaming_arena', 'no_of_ posts': '390 posts', 'no_of_followers': '42,000 followers', 'no_of_following': '42,000 followers', 'name': 'Gaming Arena', 'type_of_page': 'Gaming', 'bio': '🎮 PC & Mobile Games\n🔥 Live Streams Daily\n📩 Brand Collaborations\ngamingarena.gg'}, {'username': 'fashion_by_isha', 'no_of_ posts': '620 posts', 'no_of_followers': '28,000 followers', 'no_of_following': '28,000 followers', 'name': 'Isha | Fashion Creator', 'type_of_page': 'Fashion', 'bio': '👗 Daily Outfit Inspiration\n✨ Beauty & Lifestyle\n📩 DM for promotions\nfashionbyisha.com'}, {'username': 'finance_with_kunal', 'no_of_ posts': '205 posts', 'no_of_followers': '17,000 followers', 'no_of_following': '17,000 followers', 'name': 'Kunal | Finance', 'type_of_page': 'Finance', 'bio': '📈 Stock Market\n💰 Investing Tips\n📩 Business inquiries\nfinancewithkunal.in'}, {'username': 'pet_lovers_club', 'no_of_ posts': '315 posts', 'no_of_followers': '11,000 followers', 'no_of_following': '11,000 followers', 'name': 'Pet Lovers Club', 'type_of_page': 'Animals', 'bio': '🐶 Dogs | Cats | Pets\n❤️ Pet Care Tips\n📩 Feature your pet\npetloversclub.com'}, {'username': 'music_vibes', 'no_of_ posts': '870 posts', 'no_of_followers': '39,000 followers', 'no_of_following': '39,000 followers', 'name': 'Music Vibes', 'type_of_page': 'Music', 'bio': '🎵 Discover New Songs\n🎧 Daily Playlists\n📩 Promotions Open\nmusicvibes.fm'}, {'username': 'art_by_sana', 'no_of_ posts': '154 posts', 'no_of_followers': '8,900 followers', 'no_of_following': '8,900 followers', 'name': 'Sana | Artist', 'type_of_page': 'Art', 'bio': '🎨 Digital & Traditional Art\n🖌️ Commission Open\n📩 DM to Order\nartbysana.com'}, {'username': 'daily_motivation', 'no_of_ posts': '1,020 posts', 'no_of_followers': '55,000 followers', 'no_of_following': '55,000 followers', 'name': 'Daily Motivation', 'type_of_page': 'Education', 'bio': '🔥 Quotes & Success Stories\n🌟 Inspire  ...

# %%
import json
s = json.dumps(all_chunks, indent= 4)
print(s)
# Out:
# [
#     {
#         "username": "tech_world_raj",
#         "no_of_ posts": "210 posts",
#         "no_of_followers": "12,500 followers",
#         "no_of_following": "12,500 followers",
#         "name": "Raj | Tech Reviews",
#         "type_of_page": "Science & Technology",
#         "bio": "Smartphones | AI | Gadgets Honest reviews & tips DM for collaborations\ntechworldraj.com"
#     },
#     {
#         "username": "fit_with_aarav",
#         "no_of_ posts": "540 posts",
#         "no_of_followers": "18,000 followers",
#         "no_of_following": "18,000 followers",
#         "name": "Aarav | Fitness Coach",
#         "type_of_page": "Health & Wellness",
#         "bio": "\ud83d\udcaa Transform Your Body\nDiet | Workout | Motivation\nOnline coaching available\nfitwithaarav.in"
#     },
#     {
#         "username": "travel_diaries_riya",
#         "no_of_ posts": "185 posts",
#         "no_of_followers": "9,800 followers",
#         "no_of_following": "9,800 followers",
#         "name": "Riya | Travel Blogger",
#         "type_of_page": "Travel",
#         "bio": "Exploring Hidden Places\nBudget Travel Tips\nDM for partnerships\nriyatravels.com"
#     },
#     {
#         "username": "foodie_krishna",
#         "no_of_ posts": "760 posts",
#         "no_of_followers": "22,000 followers",
#         "no_of_following": "22,000 followers",
#         "name": "Krishna | Food Lover",
#         "type_of_page": "Food & Drink",
#         "bio": "Street Food Explorer\nReviews & Recipes\nDM for collabs\nzomato.com"
#     },
#     {
#         "username": "code_with_neha",
#         "no_of_ posts": "134 posts",
#         "no_of_followers": "15,000 followers",
#         "no_of_following": "15,000 followers",
#         "name": "Neha | Software Engineer",
#         "type_of_page": "Education",
#         "bio": "\ud83d\udcbb Python | DSA | AI\n\ud83d\ude80 Helping Beginners Learn Coding\n\ud83d\udce9 Workshops & Mentorship\ncodewithneha.dev"
#     },
#     {
#         "username": "startup_guru",
#         "no_of_ posts": "98 posts",
#         "no_of_followers": "31,000 followers",
#         "no_of_following": "31,000 followers",
#         "name": "Startup Guru",
#         "type_of_page": "Business",
#         "bio": "\ud83d\ude80 Startup News & Funding\n\ud83d\udcbc Founder Stories\n\ud83d\udce9 Feature your startup\nstartupguru.in"
#     },
#     {
#         "username": "nature_clicks",
#         "no_of_ posts": "480 posts",
#         "no_of_followers": "14,000 followers",
#         "no_of_following": "14,000 followers",
#         "name": "Nature Clicks",
#         "type_of_page": "Photography",
#         "bio": "\ud83c\udf3f Wildlife & Landscapes\n\ud83d\udcf8 Shot on DSLR\n\ud83d\udce9 Prints Available\nnatureclicks.com"
#     },
#     {
#         "username": "gaming_arena",
#         "no_of_ posts": "390 posts",
#         "no_of_followers": "42,000 followers",
#         "no_of_following": "42,000 followers",
#         "name": "Gaming Arena",
#         "type_of_page": "Gaming",
#         "bio": "\ud83c\udfae PC & Mobile Games\n\ud83d\udd25 Live Streams Daily\n\ud83d\udce9 Brand Collaborations\ngamingarena.gg"
#     },
#     {
#         "username": "fashion_by_isha",
#         "no_of_ posts": "620 posts",
#         "no_of_followers": "28,000 followers",
#         "no_of_following": "28,000 followers",
#         "name": "Isha | Fashion Creator",
#         "type_of_page": "Fashion",
#         "bio": "\ud83d\udc57 Daily Outfit Inspiration\n\u2728 Beauty & Lifestyle\n\ud83d\udce9 DM for promotions\nfashionbyisha.com"
#     },
#     {
#         "username": "finance_with_kunal",
#         "no_of_ posts": "205 posts",
#         "no_of_followers": "17,000 followers",
#         "no_of_following": "17,000 followers",
#         "name": "Kunal | Finance",
#         "type_of_page": "Finance",
#         "bio": "\ud83d\udcc8 Stock Market\n\ud83d\udcb0 Investing Tips\n\ud83d\udce9 Business inquiries\nfinancewithkunal.in"
#     },
#     {
#         "username": "pet_lovers_club",
#         "no_of_ posts": "315 posts",
#         "no_of_followers": "11,000 followers",
#         "no_of_following": "11,000 followers",
#         "name": "Pet Lovers Club",
#         "type_of_page": "Animals",
#         "bio": "\ud83d\udc36 Dogs | Cats | Pets\n\u2764\ufe0f Pet Care Tips\n\ud83d\udce9 Feature your pet\npetloversclub.com"
#     },
#     {
#         "username": "music_vibes",
#         "no_of_ posts": "870 posts",
#         "no_of_followers": "39,000 followers",
#         "no_of_following": "39,000 followers",
#         "name": "Music Vibes",
#         "type_of_page": "Music",
#         "bio": "\ud83c\udfb5 Discover New Songs\n\ud83c\udfa7 Daily Playlists\n\ud83d\udce9 Promotions Open\nmusicvibes.fm"
#     },
#     {
#         "username": "art_by_sana",
#         "no_of_ posts": "154 posts",
#         "no_of_followers": "8,900 followers",
#         "no_of_following": "8,900 followers",
#         "name": "Sana | Artist",
#         "type_of_page": "Art",
#         "bio": "\ud83c\udfa8 Digital & Traditional Art\n\ud83d\udd8c\ufe0f Commission Open\n\ud83d\udce9 DM to Order\nartbysana.com"
#     },
#     {
#         "username": "daily_motivation",
#         "no_of_ posts": "1,020 posts",
#         "no_of_followers": "55,000 followers",
#         "no_of_following": "55,000 followers",
#         "name": "Daily Motivation",
#         "type_of_page": "Education",
#         "bio": "\ud83d\udd25 Quotes & Success Stories\n\ud83c\udf1f Inspire Every Day\n\ud83d\udce9 Partnership Requests\ndailymotivation.in"
#     },
#     {
#         "username": "ai_future_lab",
#         "no_of_ posts": "265 posts",
#         "no_of_followers": "26,000 followers",
#         "no_of_following": "26,000 followers",
#         "name": "AI Future Lab",
#         "type_of_page": "Artificial Intelligence",
#         "bio": "\ud83e\udd16 AI Tools & News\n\ud83e\udde0 Machine Learning Updates\n\ud83d\udce9 Business Contact\naifuturelab.ai"
#     }
# ]
